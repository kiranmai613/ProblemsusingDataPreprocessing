# %% [markdown]
# <a href="https://colab.research.google.com/github/kiranmai613/ProblemsusingDataPreprocessing/blob/main/2_3_Obesity_Trends_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')
df
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc  \
# 0           2011     2011           AL      Alabama
# 1           2011     2011           AL      Alabama
# 2           2011     2011           AL      Alabama
# 3           2011     2011           AL      Alabama
# 4           2011     2011           AL      Alabama
# ...          ...      ...          ...          ...
# 10971       2011     2011           KS       Kansas
# 10972       2011     2011           KS       Kansas
# 10973       2011     2011           KS       Kansas
# 10974       2011     2011           KS       Kansas
# 10975       2011     2011           KS       Kansas
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10976 entries, 0 to 10975
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   10976 non-null  int64
#  1   YearEnd                     10976 non-null  int64
#  2   LocationAbbr                10976 non-null  object
#  3   LocationDesc                10976 non-null  object
#  4   Datasource                  10976 non-null  object
#  5   Class                       10976 non-null  object
#  6   Topic                       10976 non-null  object
#  7   Question                    10976 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             10975 non-null  object
#  10  Data_Value                  10028 non-null  float64
#  11  Data_Value_Alt              10028 non-null  float64
#  12  Data_Value_Footnote_Symbol  947 non-null    object
# ...

# %%
df.isna().sum()*100/len(df)
# Out:
# YearStart                       0.000000
# YearEnd                         0.000000
# LocationAbbr                    0.000000
# LocationDesc                    0.000000
# Datasource                      0.000000
# Class                           0.000000
# Topic                           0.000000
# Question                        0.000000
# Data_Value_Unit               100.000000
# Data_Value_Type                 0.009111
# Data_Value                      8.637026
# Data_Value_Alt                  8.637026
# Data_Value_Footnote_Symbol     91.372085
# Data_Value_Footnote            91.372085
# Low_Confidence_Limit            8.637026
# High_Confidence_Limit           8.637026
# Sample_Size                     8.637026
# Total                          96.419461
# Age(years)                     78.553207
# Education                      85.714286
# Gender                         92.811589
# Income                         75.036443
# Race/Ethnicity                 71.474125
# ...

# %%
# Checking if the column is duplicate
df['Data_Value'].equals(df['Data_Value_Alt'])
# Out:
# True

# %%
# Checking correlation b/w target variable and others
df.corr()['Data_Value']
# Out:
# <ipython-input-11-70b0fca3aaf8>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Data_Value']
# YearStart                -0.044366
# YearEnd                  -0.044366
# Data_Value_Unit                NaN
# Data_Value                1.000000
# Data_Value_Alt            1.000000
# Low_Confidence_Limit      0.959088
# High_Confidence_Limit     0.944409
# Sample_Size              -0.014830
# LocationID               -0.016715
# Name: Data_Value, dtype: float64

# %%
# Dropping unnecessary columns
df.drop(['StratificationCategoryId1','StratificationID1','ClassID','Class','Datasource','DataValueTypeID','Data_Value_Type','LocationID','Sample_Size','YearEnd','YearStart','Data_Value_Alt','Data_Value_Unit','Data_Value_Footnote_Symbol','Data_Value_Footnote','Total','Age(years)','Education','Gender','Income','Race/Ethnicity'],axis = 1,inplace = True)
df
# Out:
#       LocationAbbr LocationDesc                         Topic  \
# 0               AL      Alabama       Obesity / Weight Status
# 1               AL      Alabama       Obesity / Weight Status
# 2               AL      Alabama       Obesity / Weight Status
# 3               AL      Alabama       Obesity / Weight Status
# 4               AL      Alabama       Obesity / Weight Status
# ...            ...          ...                           ...
# 10971           KS       Kansas  Physical Activity - Behavior
# 10972           KS       Kansas  Physical Activity - Behavior
# 10973           KS       Kansas  Physical Activity - Behavior
# 10974           KS       Kansas  Physical Activity - Behavior
# 10975           KS       Kansas  Physical Activity - Behavior
#
#                                                 Question  Data_Value  \
# 0      Percent of adults aged 18 years and older who ...        32.0
# 1      Percent of adults aged 18 years and older who ...        32.3
# ...

# %%
df.StratificationCategory1.value_counts()
# Out:
# Race/Ethnicity    3131
# Income            2740
# Age (years)       2354
# Education         1568
# Gender             789
# Total              393
# Name: StratificationCategory1, dtype: int64

# %%
df.isna().sum()
# Out:
# LocationAbbr                 0
# LocationDesc                 0
# Topic                        0
# Question                     0
# Data_Value                 948
# Low_Confidence_Limit       948
# High_Confidence_Limit      948
# GeoLocation                 10
# TopicID                      1
# QuestionID                   1
# StratificationCategory1      1
# Stratification1              1
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(df['High_Confidence_Limit '])
# Out:
# <Axes: >

# %%
# Dealing with null values
df['Data_Value'].fillna(df['Data_Value'].mode()[0],inplace = True)
df['Low_Confidence_Limit'].fillna(df['Low_Confidence_Limit'].mode()[0],inplace = True)
df['High_Confidence_Limit '].fillna(df['High_Confidence_Limit '].mode()[0],inplace = True)
df.head(1)
# Out:
#   LocationAbbr LocationDesc                    Topic  \
# 0           AL      Alabama  Obesity / Weight Status
#
#                                             Question  Data_Value  \
# 0  Percent of adults aged 18 years and older who ...        32.0
#
#    Low_Confidence_Limit  High_Confidence_Limit   \
# 0                  30.5                    33.5
#
#                                GeoLocation TopicID QuestionID  \
# 0  (32.84057112200048, -86.63186076199969)    OWS1       Q036
#
#   StratificationCategory1 Stratification1
# 0                   Total           Total

# %%
# converting text to numerical values
from sklearn.preprocessing import LabelEncoder
columns = ['LocationAbbr','LocationDesc','Topic','TopicID','Question','QuestionID','GeoLocation','StratificationCategory1','Stratification1']
le = LabelEncoder()

for cols in columns:
    df[cols] = le.fit_transform(df[cols])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10976 entries, 0 to 10975
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LocationAbbr             10976 non-null  int64
#  1   LocationDesc             10976 non-null  int64
#  2   Topic                    10976 non-null  int64
#  3   Question                 10976 non-null  int64
#  4   Data_Value               10976 non-null  float64
#  5   Low_Confidence_Limit     10976 non-null  float64
#  6   High_Confidence_Limit    10976 non-null  float64
#  7   GeoLocation              10976 non-null  int64
#  8   TopicID                  10976 non-null  int64
#  9   QuestionID               10976 non-null  int64
#  10  StratificationCategory1  10976 non-null  int64
#  11  Stratification1          10976 non-null  int64
# dtypes: float64(3), int64(9)
# memory usage: 1.0 MB

# %%
col = ['Data_Value','Low_Confidence_Limit','High_Confidence_Limit ']
for i in col:
    sns.boxplot(df[i],orient = 'h')
    plt.title(i)
    plt.show()

# %%
# Dealing with outliers
df = df[(df['High_Confidence_Limit ']>5) & (df['High_Confidence_Limit ']<85)]
# dealing with duplicates if any
df.drop_duplicates(inplace = True)
df.reset_index(inplace = True, drop = True)

# %%
# spliiting data
x = df.drop(['Data_Value'],axis = 1)
y = df['Data_Value']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (8373, 11) (8373,) (2094, 11) (2094,)

# %%
# Using StandardScaler to bring data on same scale
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)
# GridSearchCV to check the best model and best parameters

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit 
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn.model_selection import GridSearchCV

def find_best_model(x, y):
    ml = {
        'KNeighbors_Regressor': {
            'model': KNeighborsRegressor(),
            'params': {
                'n_neighbors': [3, 5, 7, 9],
                'weights': ['uniform', 'distance'],
                'p': [1, 2]
            }
        },
        'Linear_Regression': {
            'model': LinearRegression(),
            'params': {
                'fit_intercept': [True, False]
            }
        }
    }
    scores = []
    for ml_name, mp in ml.items():
        gs = GridSearchCV(mp['model'], mp['params'], cv=5, scoring='neg_mean_squared_error')
        gs.fit(x, y)
        scores.append({
            'model': ml_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })
    return pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])

find_best_model(x, y)
# Out:
#                   model  best_score  \
# 0  KNeighbors_Regressor   -1.065207
# 1     Linear_Regression   -0.497601
#
#                                          best_params
# 0  {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# 1                            {'fit_intercept': True}

# %%
# Model Building
lr = LinearRegression(fit_intercept=True)
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([49.4050118 , 28.3951798 , 35.98631854, ..., 38.03415561,
#        33.79402959, 45.53010984])
